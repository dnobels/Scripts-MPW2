# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
from pathlib import Path
from scipy.stats import norm
from sklearn.metrics import mean_squared_error
import scipy
import scipy.stats
from scipy.optimize import curve_fit
from pylab import exp
from scipy import optimize
from math import sqrt
import scipy.stats as stats

# %%
def deltat(time,ch1,ch2):
    half1= max(ch1)/2
    half2= max(ch2)/2
    i=0
    while ch1[i]<half1:
        i=i+1
    j=0
    while ch2[j]<half2:
        j=j+1
    t1= time[i]
    t2= time[j]
    dt= time[j]-time[i]
    return dt, t1 ,t2

def tot(time, ch):
    half= max(ch)/2
    i=0
    while ch[i]<half:
        i=i+1
    j=i+30
    while ch[j]>half:
        j=j+1
    tott= time[j]-time[i]
    return tott

def Gaussian(x,a,b,c):
    return a * exp(-(x - b)**2.0 / (2 * c**2))

def q(tot):
    return (tot-36.10)/0.0084

# %%
data_folder = Path("/home/pixel/Documents/Master_Thesis_Douwe_Nobels/Measurements/pixel_r2_c1/L2_0")

file_to_open = data_folder / "pixel2_1_BL0_9_TH0_96_L2_000001.csv"

f = open(file_to_open)
type(f)

csvreader= csv.reader(f)
header = []
header = next(csvreader)
header

rows = []
for row in csvreader:
        rows.append(row)
data=rows[23:]
data= np.asarray(data, dtype=float)

time=data[:,0]
ch1= data[:,1]
ch2= data[:,2]

time = [i * 10**9 for i in time]

fig = plt.figure(figsize=(10,10))
plt.plot(time,ch1, label="Pulse Generator")
plt.plot(time,ch2,label="Compout")
plt.legend()
fig.patch.set_facecolor('xkcd:white')
plt.xlabel("$t$(ns)",fontsize=18)
plt.title("Continuous Pixel r2c1, L=2.0V",fontsize=22)
plt.ylabel("V",fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=20)
plt.show()

print(time[1]-time[0])
# Out:
# 0.0625

# %%
# %%time
det0=[]
tt10=[]
tt20=[]
t00=[]
max0=[]

data_folder = Path("/home/pixel/Documents/Master_Thesis_Douwe_Nobels/Measurements/pixel_r2_c1/L2_0")


for i in range(10000):
    num= str(i+1).zfill(5)
    txt1 = "pixel2_1_BL0_9_TH0_96_L2_0{number}".format(number = num)
    file_to_open = data_folder / "{txt1}.csv".format(txt1=txt1)
    f = open(file_to_open)
    csvreader= csv.reader(f)
    header = []
    header = next(csvreader)
    header

    rows = []
    for row in csvreader:
            rows.append(row)
    data=rows[23:]
    data= np.asarray(data, dtype=float)

    time=data[:,0]
    ch1= data[:,1]
    ch2= data[:,2]
    max0.append(max(ch1))
    dt,t1,t2=deltat(time,ch1,ch2)
    det0.append(dt)
    tt10.append(t1)
    tt20.append(t2)
    tott= tot(time,ch2)
    t00.append(tott)
# Out:
# CPU times: user 2min 21s, sys: 1.69 s, total: 2min 23s
# Wall time: 2min 24s

# %%
# %%time
det1=[]
tt11=[]
tt21=[]
t01=[]
max1=[]

data_folder = Path("/home/pixel/Documents/Master_Thesis_Douwe_Nobels/Measurements/pixel_r2_c1/L2_1")


for i in range(10000):
    num= str(i+1).zfill(5)
    txt1 = "pixel2_1_BL0_9_TH0_96_L2_1{number}".format(number = num)
    file_to_open = data_folder / "{txt1}.csv".format(txt1=txt1)
    f = open(file_to_open)
    csvreader= csv.reader(f)
    header = []
    header = next(csvreader)
    header

    rows = []
    for row in csvreader:
            rows.append(row)
    data=rows[23:]
    data= np.asarray(data, dtype=float)

    time=data[:,0]
    ch1= data[:,1]
    ch2= data[:,2]
    max1.append(max(ch1))
    dt,t1,t2=deltat(time,ch1,ch2)
    det1.append(dt)
    tt11.append(t1)
    tt21.append(t2)
    tott= tot(time,ch2)
    t01.append(tott)
# Out:
# CPU times: user 2min 32s, sys: 1.75 s, total: 2min 34s
# Wall time: 2min 35s

# %%
# %%time
det2=[]
tt12=[]
tt22=[]
t02=[]
max2=[]

data_folder = Path("/home/pixel/Documents/Master_Thesis_Douwe_Nobels/Measurements/pixel_r2_c1/L2_2")


for i in range(10000):
    num= str(i+1).zfill(5)
    txt1 = "pixel2_1_BL0_9_TH0_96_L2_2{number}".format(number = num)
    file_to_open = data_folder / "{txt1}.csv".format(txt1=txt1)
    f = open(file_to_open)
    csvreader= csv.reader(f)
    header = []
    header = next(csvreader)
    header

    rows = []
    for row in csvreader:
            rows.append(row)
    data=rows[23:]
    data= np.asarray(data, dtype=float)

    time=data[:,0]
    ch1= data[:,1]
    ch2= data[:,2]
    max2.append(max(ch1))
    dt,t1,t2=deltat(time,ch1,ch2)
    det2.append(dt)
    tt12.append(t1)
    tt22.append(t2)
    tott= tot(time,ch2)
    t02.append(tott)
# Out:
# CPU times: user 2min 34s, sys: 1.76 s, total: 2min 36s
# Wall time: 2min 37s

# %%
# %%time
det3=[]
tt13=[]
tt23=[]
t03=[]
max3=[]

data_folder = Path("/home/pixel/Documents/Master_Thesis_Douwe_Nobels/Measurements/pixel_r2_c1/L2_3")


for i in range(10000):
    num= str(i+1).zfill(5)
    txt1 = "pixel2_1_BL0_9_TH0_96_L2_3{number}".format(number = num)
    file_to_open = data_folder / "{txt1}.csv".format(txt1=txt1)
    f = open(file_to_open)
    csvreader= csv.reader(f)
    header = []
    header = next(csvreader)
    header

    rows = []
    for row in csvreader:
            rows.append(row)
    data=rows[23:]
    data= np.asarray(data, dtype=float)

    time=data[:,0]
    ch1= data[:,1]
    ch2= data[:,2]
    max3.append(max(ch1))
    dt,t1,t2=deltat(time,ch1,ch2)
    det3.append(dt)
    tt13.append(t1)
    tt23.append(t2)
    tott= tot(time,ch2)
    t03.append(tott)
# Out:
# CPU times: user 2min 34s, sys: 1.78 s, total: 2min 35s
# Wall time: 2min 36s

# %%
# %%time
det4=[]
tt14=[]
tt24=[]
t04=[]
max4=[]

data_folder = Path("/home/pixel/Documents/Master_Thesis_Douwe_Nobels/Measurements/pixel_r2_c1/L2_4")


for i in range(10000):
    num= str(i+1).zfill(5)
    txt1 = "pixel2_1_BL0_9_TH0_96_L2_4{number}".format(number = num)
    file_to_open = data_folder / "{txt1}.csv".format(txt1=txt1)
    f = open(file_to_open)
    csvreader= csv.reader(f)
    header = []
    header = next(csvreader)
    header

    rows = []
    for row in csvreader:
            rows.append(row)
    data=rows[23:]
    data= np.asarray(data, dtype=float)

    time=data[:,0]
    ch1= data[:,1]
    ch2= data[:,2]
    max4.append(max(ch1))
    dt,t1,t2=deltat(time,ch1,ch2)
    det4.append(dt)
    tt14.append(t1)
    tt24.append(t2)
    tott= tot(time,ch2)
    t04.append(tott)
# Out:
# CPU times: user 2min 32s, sys: 1.87 s, total: 2min 34s
# Wall time: 2min 35s

# %%
# %%time
det5=[]
tt15=[]
tt25=[]
t05=[]
max5=[]

data_folder = Path("/home/pixel/Documents/Master_Thesis_Douwe_Nobels/Measurements/pixel_r2_c1/L2_5")


for i in range(2,10000):
    num= str(i+1).zfill(5)
    txt1 = "pixel2_1_BL0_9_TH0_96_L2_5{number}".format(number = num)
    file_to_open = data_folder / "{txt1}.csv".format(txt1=txt1)
    f = open(file_to_open)
    csvreader= csv.reader(f)
    header = []
    header = next(csvreader)
    header

    rows = []
    for row in csvreader:
            rows.append(row)
    data=rows[23:]
    data= np.asarray(data, dtype=float)

    time=data[:,0]
    ch1= data[:,1]
    ch2= data[:,2]
    max5.append(max(ch1))
    dt,t1,t2=deltat(time,ch1,ch2)
    det5.append(dt)
    tt15.append(t1)
    tt25.append(t2)
    tott= tot(time,ch2)
    t05.append(tott)
# Out:
# CPU times: user 2min 46s, sys: 2.38 s, total: 2min 49s
# Wall time: 2min 50s

# %%
np.mean(det0)
# Out:
# 8.286165625e-08

# %%
det0= [i * 10**9 for i in det0]
det1= [i * 10**9 for i in det1]
det2= [i * 10**9 for i in det2]
det3= [i * 10**9 for i in det3]
det4= [i * 10**9 for i in det4]
det5= [i * 10**9 for i in det5]

# %%
det00=[]
det11=[]
det22=[]
det33=[]
det44=[]
det55=[]


for i in range(len(det0)):
    det00.append(det0[i]-np.mean(det0))
    
for i in range(len(det1)):
    det11.append(det1[i]-np.mean(det1))  

for i in range(len(det2)):
    det22.append(det2[i]-np.mean(det2))

for i in range(len(det3)):
    det33.append(det3[i]-np.mean(det3))

for i in range(len(det4)):
    det44.append(det4[i]-np.mean(det4))
    
for i in range(len(det5)):
    det55.append(det5[i]-np.mean(det5))

# %%
TR=[]
TE=[]

# %%
nbins=80
fig = plt.figure(figsize=(10,10))

bin_size = abs(bins[1]-bins[0])
x =np.linspace(start=bins[0]+bin_size/2.0,stop=bins[-2]+bin_size/2.0,\
num=nbins,endpoint=True)


y = n
y[y==0]= 1e-8

newy=[]
newx=[]
for i in range(len(y)):
    if y[i]>=1:
        newy.append(y[i])
        newx.append(x[i])


newy=[]
newx=[]
for i in range(len(y)):
    if y[i]>=1:
        newy.append(y[i])
        newx.append(x[i])


popt, pcov = optimize.curve_fit(Gaussian,newx,newy) 

# Curve-fit error method
error = [] 
for i in range(len(popt)):
    try:
      error.append( np.absolute(pcov[i][i])**0.5)
    except:
      error.append( 0.00 )
pfit_curvefit = popt
perr_curvefit = np.array(error) 
print('\n Curve-fit Curve fit: %s' % pfit_curvefit)
print('\n Curve-fit Fit errors: %s' % perr_curvefit)

# Plot the fit
x_fit = np.linspace(x[0], x[-1], nbins)
y_gauss = Gaussian(x_fit, *popt)
yerr=Gaussian(x_fit,*perr_curvefit)

plt.plot(x_fit, y_gauss,linestyle='--',linewidth=2,\
color='red',label='Gaussian')

TR.append(abs(popt[2]))
TE.append(perr_curvefit[2])

print(perr_curvefit[2]*1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [19], in <cell line: 28>()
#      24         newy.append(y[i])
#      25         newx.append(x[i])
# ---> 28 popt, pcov = optimize.curve_fit(Gaussian,newx,newy)
#      30 # Curve-fit error method
#      31 error = []
#
# File ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minpack_py.py:795, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, **kwargs)
#     792         xdata = np.asarray(xdata, float)
#     794 if ydata.size == 0:
# --> 795     raise ValueError("`ydata` must not be empty!")
#     797 # Determine type of sigma
#     798 if sigma is not None:
#
# ValueError: `ydata` must not be empty!

# %%
nbins=80
data = det11
n,bins,patches = plt.hist(data,bins=nbins, range=(-1.4,1.4))

# Generate data from bins as a set of points 
bin_size = abs(bins[1]-bins[0])
x =np.linspace(start=bins[0]+bin_size/2.0,stop=bins[-2]+bin_size/2.0,\
num=nbins,endpoint=True)


y = n
y[y==0]= 1e-8

newy=[]
newx=[]
for i in range(len(y)):
    if y[i]>=1:
        newy.append(y[i])
        newx.append(x[i])


newy=[]
newx=[]
for i in range(len(y)):
    if y[i]>=1:
        newy.append(y[i])
        newx.append(x[i])


popt, pcov = optimize.curve_fit(Gaussian,newx,newy) 

# Curve-fit error method
error = [] 
for i in range(len(popt)):
    try:
      error.append( np.absolute(pcov[i][i])**0.5)
    except:
      error.append( 0.00 )
pfit_curvefit = popt
perr_curvefit = np.array(error) 
print('\n Curve-fit Curve fit: %s' % pfit_curvefit)
print('\n Curve-fit Fit errors: %s' % perr_curvefit)

# Plot the fit
x_fit = np.linspace(x[0], x[-1], nbins)
y_gauss = Gaussian(x_fit, *popt)
yerr=Gaussian(x_fit,*perr_curvefit)

plt.plot(x_fit, y_gauss,linestyle='--',linewidth=2,\
color='red',label='Gaussian')

plt.title("Pulse generator amplitude 2.1V",fontsize=18)
fig.patch.set_facecolor('xkcd:white')

plt.legend()
plt.show()

TR.append(abs(popt[2]))
TE.append(perr_curvefit[2])
# Out:
#  Curve-fit Curve fit: [1.01007736e+03 5.83827064e-03 2.33685404e-01]
#
#  Curve-fit Fit errors: [1.58370452e+01 4.29926632e-03 4.30202658e-03]

# %%
nbins=80
data = det22
n,bins,patches = plt.hist(data,bins=nbins, range=(-1.4,1.4))

# Generate data from bins as a set of points 
bin_size = abs(bins[1]-bins[0])
x =np.linspace(start=bins[0]+bin_size/2.0,stop=bins[-2]+bin_size/2.0,\
num=nbins,endpoint=True)


y = n
y[y==0]= 1e-8

newy=[]
newx=[]
for i in range(len(y)):
    if y[i]>=1:
        newy.append(y[i])
        newx.append(x[i])


popt, pcov = optimize.curve_fit(Gaussian,newx,newy) 

# Curve-fit error method
error = [] 
for i in range(len(popt)):
    try:
      error.append( np.absolute(pcov[i][i])**0.5)
    except:
      error.append( 0.00 )
pfit_curvefit = popt
perr_curvefit = np.array(error) 
print('\n Curve-fit Curve fit: %s' % pfit_curvefit)
print('\n Curve-fit Fit errors: %s' % perr_curvefit)

# Plot the fit
x_fit = np.linspace(x[0], x[-1], nbins)
y_gauss = Gaussian(x_fit, *popt)
yerr=Gaussian(x_fit,*perr_curvefit)

plt.plot(x_fit, y_gauss,linestyle='--',linewidth=2,\
color='red',label='Gaussian')
plt.title("Pulse generator amplitude 2.2V",fontsize=18)
fig.patch.set_facecolor('xkcd:white')


plt.legend()
plt.show()

TR.append(abs(popt[2]))
TE.append(perr_curvefit[2])

# %%
nbins=80
data = det33
n,bins,patches = plt.hist(data,bins=nbins, range=(-1.4,1.4))

# Generate data from bins as a set of points 
bin_size = abs(bins[1]-bins[0])
x =np.linspace(start=bins[0]+bin_size/2.0,stop=bins[-2]+bin_size/2.0,\
num=nbins,endpoint=True)


y = n
y[y==0]= 1e-8

newy=[]
newx=[]
for i in range(len(y)):
    if y[i]>=1:
        newy.append(y[i])
        newx.append(x[i])


popt, pcov = optimize.curve_fit(Gaussian,newx,newy) 

# Curve-fit error method
error = [] 
for i in range(len(popt)):
    try:
      error.append( np.absolute(pcov[i][i])**0.5)
    except:
      error.append( 0.00 )
pfit_curvefit = popt
perr_curvefit = np.array(error) 
print('\n Curve-fit Curve fit: %s' % pfit_curvefit)
print('\n Curve-fit Fit errors: %s' % perr_curvefit)

# Plot the fit
x_fit = np.linspace(x[0], x[-1], nbins)
y_gauss = Gaussian(x_fit, *popt)
yerr=Gaussian(x_fit,*perr_curvefit)

plt.plot(x_fit, y_gauss,linestyle='--',linewidth=2,\
color='red',label='Gaussian')

plt.title("Pulse generator amplitude 2.3V",fontsize=18)
fig.patch.set_facecolor('xkcd:white')

plt.legend()
plt.show()

TR.append(abs(popt[2]))
TE.append(perr_curvefit[2])

# %%
nbins=80
data = det44
n,bins,patches = plt.hist(data,bins=nbins, range=(-1.4,1.4))

# Generate data from bins as a set of points 
bin_size = abs(bins[1]-bins[0])
x =np.linspace(start=bins[0]+bin_size/2.0,stop=bins[-2]+bin_size/2.0,\
num=nbins,endpoint=True)


y = n
y[y==0]= 1e-8

newy=[]
newx=[]
for i in range(len(y)):
    if y[i]>=1:
        newy.append(y[i])
        newx.append(x[i])


popt, pcov = optimize.curve_fit(Gaussian,newx,newy) 

# Curve-fit error method
error = [] 
for i in range(len(popt)):
    try:
      error.append( np.absolute(pcov[i][i])**0.5)
    except:
      error.append( 0.00 )
pfit_curvefit = popt
perr_curvefit = np.array(error) 
print('\n Curve-fit Curve fit: %s' % pfit_curvefit)
print('\n Curve-fit Fit errors: %s' % perr_curvefit)

# Plot the fit
x_fit = np.linspace(x[0], x[-1], nbins)
y_gauss = Gaussian(x_fit, *popt)
yerr=Gaussian(x_fit,*perr_curvefit)

plt.plot(x_fit, y_gauss,linestyle='--',linewidth=2,\
color='red',label='Gaussian')

plt.title("Pulse generator amplitude 2.3V",fontsize=18)
fig.patch.set_facecolor('xkcd:white')

plt.legend()
plt.show()

TR.append(abs(popt[2]))
TE.append(perr_curvefit[2])

# %%
nbins=80
data = det55
n,bins,patches = plt.hist(data,bins=nbins, range=(-1.4,1.4))

# Generate data from bins as a set of points 
bin_size = abs(bins[1]-bins[0])
x =np.linspace(start=bins[0]+bin_size/2.0,stop=bins[-2]+bin_size/2.0,\
num=nbins,endpoint=True)


y = n
y[y==0]= 1e-8

newy=[]
newx=[]
for i in range(len(y)):
    if y[i]>=1:
        newy.append(y[i])
        newx.append(x[i])


popt, pcov = optimize.curve_fit(Gaussian,newx,newy) 

# Curve-fit error method
error = [] 
for i in range(len(popt)):
    try:
      error.append( np.absolute(pcov[i][i])**0.5)
    except:
      error.append( 0.00 )
pfit_curvefit = popt
perr_curvefit = np.array(error) 
print('\n Curve-fit Curve fit: %s' % pfit_curvefit)
print('\n Curve-fit Fit errors: %s' % perr_curvefit)

# Plot the fit
x_fit = np.linspace(x[0], x[-1], nbins)
y_gauss = Gaussian(x_fit, *popt)
yerr=Gaussian(x_fit,*perr_curvefit)

plt.plot(x_fit, y_gauss,linestyle='--',linewidth=2,\
color='red',label='Gaussian')

plt.title("Pulse generator amplitude 2.3V",fontsize=18)
fig.patch.set_facecolor('xkcd:white')

plt.legend()
plt.show()

TR.append(abs(popt[2]))
TE.append(perr_curvefit[2])

# %%
V=[2,2.1,2.2,2.3,2.4,2.5]
fig = plt.figure(figsize=(7,5))
plt.errorbar(V,TR, yerr=TE, fmt="o", label="Continuous Pixel r2c1")
plt.xlabel("Pulse generator ampl(V)",fontsize=18)
plt.ylabel("Time resolution(ns)",fontsize=18)
plt.title("Time Resolution vs laser pulse generator amplitude",fontsize=22)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=14)
plt.grid()

fig.patch.set_facecolor('xkcd:white')


plt.show()

# %%
print(TR)

# %%
t00= [i * 10**9 for i in t00]
t01= [i * 10**9 for i in t01]
t02= [i * 10**9 for i in t02]
t03= [i * 10**9 for i in t03]
t04= [i * 10**9 for i in t04]
t05= [i * 10**9 for i in t05]

# %%
tott= [np.mean(t00),np.mean(t01),np.mean(t02),np.mean(t03),np.mean(t04),np.mean(t05)]
ertt= [np.std(t00),np.std(t01),np.std(t02),np.std(t03),np.std(t04),np.std(t05)]

fig = plt.figure(figsize=(7,5))
plt.errorbar(V,tott, yerr=ertt, fmt="o", label="Continuous Pixel r2c1")
plt.xlabel("Pulse generator ampl(V)",fontsize=18)
plt.ylabel("ToT(ns)",fontsize=18)

plt.title("Time over Threshold vs laser pulse generator amplitude",fontsize=18)

fig.patch.set_facecolor('xkcd:white')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=14)

plt.grid()
plt.show()

# %%
fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(15)
fig.set_figwidth(15)

ax0.hist(t00, bins=40, alpha=0.6, color='b')
ax0.set_title('L=2.0V', fontsize=25)
ax0.set_xlabel("t(ns)",fontsize=15)

ax1.hist(t01, bins=40, alpha=0.6, color='b')
ax1.set_title('L=2.1V', fontsize=25)
ax1.set_xlabel("t(ns)",fontsize=15)


ax2.hist(t02, bins=40, alpha=0.6, color='b')
ax2.set_title('L=2.2V', fontsize=25)
ax2.set_xlabel("t(ns)",fontsize=15)

ax3.hist(t03, bins=40, alpha=0.6, color='b')
ax3.set_title('L=2.3V', fontsize=25)
ax3.set_xlabel("t(ns)",fontsize=15)


fig.suptitle("Pixel r2 c1, ToT", fontsize=40)
fig.tight_layout()
plt.show()

# %%
charge=[]
for i in range(len(tott)):
    ch= q(tott[i])
    charge.append(ch)

# %%
fig = plt.figure(figsize=(10,7))
plt.errorbar(charge,TR, yerr=TE, fmt="o", label="continuous pixel r2c1")
plt.xlabel("Laser induced charge(e-)",fontsize=18)
plt.ylabel("Time resolution(ns)",fontsize=18)
plt.title("Time Resolution vs laser induced charge for pixel r2c1",fontsize=22)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=14)
plt.grid()
fig.patch.set_facecolor('xkcd:white')


plt.show()
